# %% [markdown]
# ## Pre

# %%
import pandas as pd
import numpy as np
import pymysql
from dateutil.parser import parse
from datetime import datetime
import math
import re

def calculating_age(loan_id, id_card):
    try:
        data_in = parse(re.findall(r'\d{8}', loan_id)[0])
    except IndexError:
        data_in = datetime.today()
    born = parse(id_card[6:14])
    try:
        birthday = born.replace(year=data_in.year)
    except ValueError:
        birthday = born.replace(year=data_in.year, day=28)
    if birthday > born:
        return data_in.year - born.year - 1
    else:
        return data_in.year - born.year

def get_area(x):
    y = ''
    if x == 0:
        y = '市区'
    elif (x == 1) | (x == 2):
        y = '偏远区县'
    elif (x == 3) | (x == 4) | (x == 5):
        y = '村、乡'
    elif x == 8:
        y = '县级市'
    return y


def get_city_area(x):
    y = ''
    if (re.search(r'县', x) != None):
        y = '县'
    elif (re.search(r'市|区',x) != None):
        y = '市'
    return y


def city_match(x1, x2):
    return True if (re.search(x1, x2) != None) else False


def handle_inf(x):
    return 0 if math.isinf(x) else x

def get_max(x, y):
    return x if x >= y else y

# 随机将样本切分为n等份
def split_random(df, n):
    df = df.sample(frac=1)
    point = int(int(1/n * df.shape[0]))
    cut_index = range(point, df.shape[0], point)
    dfc1 = df[0: cut_index[0]]
    dfc = [df[cut_index[cut_index.index(i)-1]: i] for i in cut_index]
    dfc.append(dfc1)
    return dfc

# 设定训练集

def set_train_test(df, n, test_num):
    df_test = df[test_num]
    n_list = list(range(0, n))
    n_list.remove(test_num)
    print(n_list)
    df_train = pd.concat(df[i]for i in n_list)
    df_train['train_test'] = 1
    df_test['train_test'] = 0
    df = pd.concat([df_train, df_test])
    return df

def cal_woe(df, classification, col_count, feature_list, other_var):
    save_path = r'd:\hoomsun_data\analysis\models\贡献值结果-{}.xlsx'.format(str(datetime.today())[0:13])
    writer = pd.ExcelWriter(save_path)
    df_IV = pd.DataFrame(columns=['英文', 'IV值'])
    index = 0
    offset = 0
    df_train = df[df.train_test == 1]
    for i in feature_list:
        print(i)
        pt = pd.pivot_table(df_train, index=classification, columns=i, values=col_count, aggfunc='count').T
        print(pt)
        pt['WOEi'] = np.log((pt['good']/pt['good'].sum())/(pt['bad']/pt['bad'].sum())).round(4)
        pt['IVi'] = pt.WOEi.mul((pt.good/pt.good.sum())-(pt.bad/pt.bad.sum())).round(3)
        pt = pt.fillna(0)
        pt.to_excel(writer, 'woe明细', startrow=offset)
        key = pt.index.tolist()
        value = pt.WOEi.tolist()
        dict_v = dict(zip(key, value))
        print(dict_v)
        df[i] = df[i].map(dict_v)   # 将woe值注入测试集
        iv = pt.IVi.sum()
        df_IV.at[index, '英文'] = i
        df_IV.at[index, 'IV值'] = iv
        index += 1
        offset += (pt.shape[0] + 2)
    pd.merge(df_IV, df_list, on='英文', how='left').to_excel(writer, sheet_name='IV汇总')
    woe_value = df[other_var + feature_list].copy()
    woe_value.to_excel(writer, sheet_name='woe', index=False)
    writer.save()

# %%
df1 = pd.read_excel

# %%
df = pd.read_csv(r'd:\hoomsun_data\analysis\models\data_8.28.csv')
df = df.fillna('缺失')

df_list = pd.read_excel(r'd:\hoomsun_data\analysis\models\建模字典v4(2).xlsx')
list_var = list(df_list[df_list.是否使用==1]['英文'])
# df = df[df.classification != 'unknow']
# df['product'] = df['con_product_name']
dfc = split_random(df, 5)
df_split = set_train_test(dfc, 5, 1)
cal_woe(df_split, 'classification', 'loan_id', feature_list=list_var,
        other_var=['loan_id', 'classification', 'user_mark', 'train_test'])
# Out:
# [0, 2, 3, 4]
# cust_sex
# classification   bad  good
# cust_sex
# 女               1340  4373
# 男               3898  9205
# {'女': 0.2303, '男': -0.0932}
# marital_status
# classification   bad  good
# marital_status
# 丧偶                29    61
# 再婚                11    14
# 已婚              3585  9875
# 未婚               837  2024
# 离婚               772  1600
# 缺失                 4     4
# {'丧偶': -0.2089, '再婚': -0.7113, '已婚': 0.0607, '未婚': -0.0695, '离婚': -0.2237, '缺失': -0.9525}
# rresidence_prov_name
# classification           bad    good
# rresidence_prov_name
# 上海市                    154.0   438.0
# 云南省                    216.0   520.0
# 内蒙古自治区                  11.0    23.0
# 北京市                      2.0   143.0
# 吉林省                     14.0    23.0
# 四川省                    304.0   845.0
# 天津市                     15.0   193.0
# 宁夏回族自治区                101.0   134.0
# 安徽省                    197.0   530.0
# 山东省                   1060.0  2434.0
# 山西省                     10.0    43.0
# 广东省                     14.0    29.0
# 广西壮族自治区                535.0  1119.0
# 新疆维吾尔自治区                 1.0     8.0
# 江苏省                    440.0  1179.0
# 江西省                     18.0    31.0
# 河北省                    273.0   908.0
# 河南省                    261.0   498.0
# 浙江省                    238.0   584.0
# 海南省                      NaN     2.0
# 湖北省                    171.0   305.0
# 湖南省                     74.0   432.0
# 甘肃省                    184.0   648.0
# 福建省                      9.0    29.0
# 缺失                       4.0     4.0
# 西藏自治区                    8.0    63.0
# 贵州省                    353.0   531.0
# 辽宁省                     11.0    39.0
# 重庆市                     60.0   306.0
# 陕西省                    414.0  1210.0
# 青海省                     60.0   257.0
# 黑龙江省                    26.0    70.0
# {'上海市': 0.0928, '云南省': -0.074, '内蒙古自治区': -0.2149, '北京市': 3.3172, '吉林省': -0.4561, '四川省': 0.0698, '天津市': 1.6021, '宁夏回族自治区': -0.6698, '安徽省': 0.0372, '山东省': -0.1212, '山西省': 0.5061, '广东省': -0.2243, '广西壮族自治区': -0.2146, '新疆维吾尔自治区': 1.1269, '江苏省': 0.0331, '江西省': -0.4089, '河北省': 0.2493, '河南省': -0.3064, '浙江省': -0.0549, '海南省': 0.0, '湖北省': -0.3739, '湖南省': 0.8118, '甘肃省': 0.3064, '福建省': 0.2176, '缺失': -0.9525, '西藏自治区': 1.1112, '贵州省': -0.5442, '辽宁省': 0.3132, '重庆市': 0.6767, '陕西省': 0.12, '青海省': 0.5022, '黑龙江省': 0.0379}
# live_conditions
# classification    bad  good
# live_conditions
# 亲属住房              902  2672
# 单位住房              437   850
# 按揭商品房              21   412
# 无按揭商品房             39   583
# 租用                715  1745
# 缺失               1080  1045
# 自住               2044  6271
# {'亲属住房': 0.1335, '单位住房': -0.2872, '按揭商品房': 2.024, '无按揭商品房': 1.7521, '租用': -0.0603, '缺失': -0.9855, '自住': 0.1685}
# company_kind_va
# classification    bad  good
# company_kind_va
# 个体                697  2141
# 其他                 22   235
# 合资                213   299
# 国有股份             1032  2333
# 外资                127   199
# 机关事业             1334  3758
# 私企                322   257
# 私营                509  1433
# 缺失                982  2923
# {'个体': 0.1697, '其他': 1.416, '合资': -0.6134, '国有股份': -0.1369, '外资': -0.5034, '机关事业': 0.0832, '私企': -1.178, '私营': 0.0826, '缺失': 0.1383}
# private_type
# classification   bad  good
# private_type
# 个体工商户            378  1067
# 其他               116  2118
# 合伙企业               9    64
# 有限责任公司           203   850
# 独资                19    34
# 缺失              4501  9343
# 股份有限公司            12   102
# {'个体工商户': 0.0852, '其他': 1.9521, '合伙企业': 1.0091, '有限责任公司': 0.4795, '独资': -0.3706, '缺失': -0.2222, '股份有限公司': 1.1876}
# industry
# classification         bad    good
# industry
# 交通、能源、矿产、冶金冶炼        242.0   446.0
# 交通运输、仓储和邮政            10.0   192.0
# 住宿和餐饮业                12.0   204.0
# 信息传输、计算机服务和软件业         6.0   162.0
# 党政、国家机构              275.0   611.0
# 公共管理和社会组织              7.0   135.0
# 公用事业、生活服务           1204.0  2826.0
# 其它                  1098.0  2787.0
# 农、林、牧、渔业              10.0    53.0
# 制造业                   22.0   307.0
# 化工                    30.0    51.0
# 医药、卫生、保健             219.0   515.0
# 卫生、社会保障和社会福利          10.0   127.0
# 印刷、包装、造纸              43.0    45.0
# 商务服务、广告、物流           119.0   214.0
# 居家生活用品                82.0   144.0
# 居民服务和其他服务             18.0   384.0
# 工程、建筑、房地产、装潢         122.0   256.0
# 建筑业                   11.0    82.0
# 房地产业                   NaN    13.0
# 批发和零售                 28.0   602.0
# 教育                     4.0   173.0
# 文体休闲用品、礼品、工艺品         22.0    34.0
# 文化、体育和娱乐业              3.0   118.0
# 服装、皮革、纺织             133.0   209.0
# 机械、设备、仪器、仪表及专业用品     226.0   311.0
# 水利、环境和公共设施管理           1.0    46.0
# 电力、燃气及水的生产和供应          6.0    72.0
# 电子、电工、电器             154.0   170.0
# 社会团体                   2.0    11.0
# 科学、教育、文化             331.0   777.0
# 科学研究、技术服务和地质勘查         7.0    36.0
# 租赁和商务服务                1.0    39.0
# 粮油、食品、农林牧渔           116.0   173.0
# 缺失                    41.0    48.0
# 网络营销                  12.0    30.0
# 计算机、互联网、通讯、办公设备及用品   117.0   215.0
# 金属、非金属材料及制品          110.0   154.0
# 金融、保险、贸易             120.0   280.0
# 金融业                    2.0    57.0
# 餐饮、娱乐、购物、旅游          262.0   469.0
# {'交通、能源、矿产、冶金冶炼': -0.3411, '交通运输、仓储和邮政': 2.0024, '住宿和餐饮业': 1.8807, '信息传输、计算机服务和软件业': 2.3433, '党政、国家机构': -0.1542, '公共管理和社会组织': 2.0069, '公用事业、生活服务': -0.0993, '其它': -0.021, '农、林、牧、渔业': 0.7152, '制造业': 1.6833, '化工': -0.4219, '医药、卫生、保健': -0.0974, '卫生、社会保障和社会福利': 1.5891, '印刷、包装、造纸': -0.907, '商务服务、广告、物流': -0.3657, '居家生活用品': -0.3894, '居民服务和其他服务': 2.1078, '工程、建筑、房地产、装潢': -0.2114, '建筑业': 1.0563, '房地产业': 0.0, '批发和零售': 2.1155, '教育': 2.8145, '文体休闲用品、礼品、工艺品': -0.5172, '文化、体育和娱乐业': 2.7196, '服装、皮革、纺织': -0.5005, '机械、设备、仪器、仪表及专业用品': -0.6333, '水利、环境和公共设施管理': 2.8761, '电力、燃气及水的生产和供应': 1.5324, '电子、电工、电器': -0.8537, '社会团体': 0.7522, '科学、教育、文化': -0.0992, '科学研究、技术服务和地质勘查': 0.6851, '租赁和商务服务': 2.7111, '粮油、食品、农林牧渔': -0.5528, '缺失': -0.7949, '网络营销': -0.0362, '计算机、互联网、通讯、办公设备及用品': -0.344, '金属、非金属材料及制品': -0.616, '金融、保险、贸易': -0.1052, '金融业': 2.3974, '餐饮、娱乐、购物、旅游': -0.3703}
# position_val
# classification   bad  good
# position_val
# 一般正式员工          2579  5083
# 一般管理人员          1385  3657
# 中级管理人员            68    97
# 法人               426  2191
# 缺失               132   546
# 负责人              308   319
# 退休人员              13    21
# 非正式员工             13    34
# 高级管理人员           314  1630
# {'一般正式员工': -0.274, '一般管理人员': 0.0184, '中级管理人员': -0.5973, '法人': 0.6852, '缺失': 0.4673, '负责人': -0.9174, '退休人员': -0.4729, '非正式员工': 0.0089, '高级管理人员': 0.6944}
# property_type
# classification     bad    good
# property_type
# 公积金按揭购房           69.0   162.0
# 商业/公积金组合按揭购房       NaN     6.0
# 商业按揭购房           929.0  1753.0
# 持证抵押房              NaN    12.0
# 无房产              130.0  2241.0
# 无按揭购房            539.0  1657.0
# 缺失              3436.0  7622.0
# 自建房              135.0   125.0
# {'公积金按揭购房': -0.099, '商业/公积金组合按揭购房': 0.0, '商业按揭购房': -0.3175, '持证抵押房': 0.0, '无房产': 1.8946, '无按揭购房': 0.1705, '缺失': -0.1558, '自建房': -1.0295}
# card_account
# classification   bad  good
# card_account
# 0- ~0            160   308
# 1- 0~3           789  1495
# 2- 3~6           879  1953
# 3- 6~11         1373  3464
# 4- 11~13         416  1200
# 5- 13~20         975  2855
# 6- 20~           646  2303
# {'0- ~0': -0.2976, '1- 0~3': -0.3134, '2- 3~6': -0.1542, '3- 6~11': -0.0271, '4- 11~13': 0.1069, '5- 13~20': 0.1219, '6- 20~': 0.3187}
# card_notsettled
# classification    bad  good
# card_notsettled
# 0- ~0             203   399
# 1- 0~1            266   457
# 2- 1~3            627  1330
# 3- 3~5            707  1485
# 4- 5~8            962  2530
# 5- 8~13          1274  3445
# 6- 13~17          570  1713
# 7- 17~21          312  1081
# 8- 21~            317  1138
# {'0- ~0': -0.2768, '1- 0~1': -0.4113, '2- 1~3': -0.2005, '3- 3~5': -0.2104, '4- 5~8': 0.0144, '5- 8~13': 0.0423, '6- 13~17': 0.1479, '7- 17~21': 0.2901, '8- 21~': 0.3256}
# card_overdue
# classification   bad  good
# card_overdue
# 0- ~0           2315  5304
# 1- 0~2          1867  5105
# 2- 2~3           416  1283
# 3- 3~5           450  1273
# 4- 5~7           139   433
# 5- 7~             51   180
# {'0- ~0': -0.1235, '1- 0~2': 0.0534, '2- 2~3': 0.1738, '3- 3~5': 0.0874, '4- 5~7': 0.1838, '5- 7~': 0.3086}
# card_90overdue
# classification   bad   good
# card_90overdue
# 0- ~0           5116  13278
# 1- 0~            122    300
# {'0- ~0': 0.0012, '1- 0~': -0.0527}
# card_guaranty
# classification   bad   good
# card_guaranty
# 0- ~0           5205  13486
# 1- 0~             33     92
# {'0- ~0': -0.0005, '1- 0~': 0.0728}
# housing_loan_account
# classification         bad  good
# housing_loan_account
# 0- ~0                 3601  9138
# 1- 0~1                1420  3640
# 2- 1~2                 170   641
# 3- 2~                   47   159
# {'0- ~0': -0.0213, '1- 0~1': -0.0112, '2- 1~2': 0.3747, '3- 2~': 0.2662}
# housing_loan_notsettled
# classification            bad   good
# housing_loan_notsettled
# 0- ~0                    4138  10851
# 1- 0~1                   1058   2587
# 2- 1~                      42    140
# {'0- ~0': 0.0115, '1- 0~1': -0.0584, '2- 1~': 0.2515}
# housing_loan_overdue
# classification         bad   good
# housing_loan_overdue
# 0- ~0                 4755  12289
# 1- 0~1                 471   1239
# 2- 1~                   12     50
# {'0- ~0': -0.003, '1- 0~1': 0.0147, '2- 1~': 0.4746}
# housing_loan_90overdue
# classification           bad   good
# housing_loan_90overdue
# 0- ~0                   5230  13559
# 1- 0~                      8     19
# {'0- ~0': 0.0001, '1- 0~': -0.0875}
# housing_loan_guaranty
# classification          bad   good
# housing_loan_guaranty
# 0- ~0                  5211  13497
# 1- 0~                    27     81
# {'0- ~0': -0.0008, '1- 0~': 0.1461}
# other_loan_account
# classification       bad  good
# other_loan_account
# 0- ~0                447   654
# 1- 0~11             3589  8966
# 2- 11~15             401  1166
# 3- 15~22             362  1158
# 4- 22~31             203   731
# 5- 31~50             165   587
# 6- 50~                71   316
# {'0- ~0': -0.572, '1- 0~11': -0.0369, '2- 11~15': 0.1149, '3- 15~22': 0.2103, '4- 22~31': 0.3287, '5- 31~50': 0.3166, '6- 50~': 0.5406}
# other_loan_notsettled
# classification          bad  good
# other_loan_notsettled
# 0- ~0                   695  1120
# 1- 0~3                 2273  5817
# 2- 3~9                 1811  5033
# 3- 9~11                 160   515
# 4- 11~                  299  1093
# {'0- ~0': -0.4753, '1- 0~3': -0.0128, '2- 3~9': 0.0696, '3- 9~11': 0.2165, '4- 11~': 0.3437}
# other_loan_overdue
# classification       bad   good
# other_loan_overdue
# 0- ~0               4135  10819
# 1- 0~1               776   1854
# 2- 1~2               203    580
# 3- 2~                124    325
# {'0- ~0': 0.0093, '1- 0~1': -0.0816, '2- 1~2': 0.0973, '3- 2~': 0.011}
# other_loan_90overdue
# classification         bad   good
# other_loan_90overdue
# 0- ~0                 5195  13468
# 1- 0~                   43    110
# {'0- ~0': 0.0001, '1- 0~': -0.0132}
# other_loan_guaranty
# classification        bad   good
# other_loan_guaranty
# 0- ~0                4823  12625
# 1- 0~1                268    644
# 2- 1~2                 76    148
# 3- 2~                  71    161
# {'0- ~0': 0.0098, '1- 0~1': -0.0758, '2- 1~2': -0.286, '3- 2~': -0.1338}
# card_count_only_rmb
# classification          bad    good
# card_count_only_rmb
# -99                     NaN     2.0
# 0- ~0                 160.0   307.0
# 1- 0~1                328.0   561.0
# 2- 1~2                408.0   791.0
# 3- 2~5               1257.0  2869.0
# 4- 5~8               1263.0  3227.0
# 5- 8~10               654.0  1860.0
# 6- 10~12              452.0  1381.0
# 7- 12~                716.0  2580.0
# {'-99': 0.0, '0- ~0': -0.3008, '1- 0~1': -0.4158, '2- 1~2': -0.2905, '3- 2~5': -0.1273, '4- 5~8': -0.0144, '5- 8~10': 0.0927, '6- 10~12': 0.1644, '7- 12~': 0.3294}
# card_count_card_notsettled
# classification                 bad    good
# card_count_card_notsettled
# -99                            NaN     2.0
# 0- ~0                        245.0   477.0
# 1- 0~1                       427.0   813.0
# 2- 1~2                       497.0  1069.0
# 3- 2~5                      1522.0  3719.0
# 4- 5~8                      1380.0  3720.0
# 5- 8~10                      605.0  1668.0
# 6- 10~12                     299.0  1057.0
# 7- 12~                       263.0  1053.0
# {'-99': 0.0, '0- ~0': -0.2863, '1- 0~1': -0.3086, '2- 1~2': -0.1866, '3- 2~5': -0.0591, '4- 5~8': 0.0391, '5- 8~10': 0.0616, '6- 10~12': 0.3102, '7- 12~': 0.4347}
# card_date_first_status
# classification             bad    good
# card_date_first_status
# 其他                         4.0     6.0
# 呆账                         1.0     NaN
# 未激活                      207.0   660.0
# 正常                      3351.0  8401.0
# 缺失                       160.0   309.0
# 逾期                         6.0    32.0
# 销户                      1231.0  3536.0
# 降额                       278.0   634.0
# {'其他': -0.547, '呆账': 0.0, '未激活': 0.207, '正常': -0.0334, '缺失': -0.2943, '逾期': 0.7215, '销户': 0.1027, '降额': -0.1281}
# card_credit_history
# classification          bad    good
# card_credit_history
# -99                     NaN     2.0
# 0- ~6                 452.0   649.0
# 1- 6~12               306.0   373.0
# 2- 12~24              453.0   909.0
# 3- 24~36              452.0   958.0
# 4- 36~48              408.0   978.0
# 5- 48~60              458.0  1050.0
# 6- 60~120            1991.0  5639.0
# 7- 120~180            589.0  2506.0
# 8- 180~               129.0   514.0
# {'-99': 0.0, '0- ~6': -0.5908, '1- 6~12': -0.7545, '2- 12~24': -0.2561, '3- 24~36': -0.2013, '4- 36~48': -0.0783, '5- 48~60': -0.1228, '6- 60~120': 0.0886, '7- 120~180': 0.4955, '8- 180~': 0.4299}
# card_credit_history_normal
# classification                 bad    good
# card_credit_history_normal
# -99                            NaN     2.0
# 0- ~6                        620.0  1024.0
# 1- 6~12                      403.0   538.0
# 2- 12~24                     643.0  1312.0
# 3- 24~36                     612.0  1357.0
# 4- 36~48                     520.0  1293.0
# 5- 48~60                     527.0  1287.0
# 6- 60~120                   1529.0  4969.0
# 7- 120~180                   333.0  1585.0
# 8- 180~                       51.0   211.0
# {'-99': 0.0, '0- ~6': -0.4508, '1- 6~12': -0.6636, '2- 12~24': -0.2393, '3- 24~36': -0.1562, '4- 36~48': -0.0416, '5- 48~60': -0.0596, '6- 60~120': 0.2261, '7- 120~180': 0.6077, '8- 180~': 0.4675}
# card_award_first
# classification     bad  good
# card_award_first
# -99                160   309
# 0- ~4000          2315  6007
# 1- 4000~8000       842  1883
# 2- 8000~12000      570  1395
# 3- 12000~17000     351   825
# 4- 17000~25000     376  1016
# 5- 25000~35000     189   641
# 6- 35000~50000     225   789
# 7- 50000~75000     114   424
# 8- 75000~           96   289
# {'-99': -0.2943, '0- ~4000': 0.001, '1- 4000~8000': -0.1477, '2- 8000~12000': -0.0575, '3- 12000~17000': -0.0979, '4- 17000~25000': 0.0415, '5- 25000~35000': 0.2688, '6- 35000~50000': 0.3022, '7- 50000~75000': 0.361, '8- 75000~': 0.1496}
# card_award_first_normal
# classification            bad  good
# card_award_first_normal
# -99                       269   551
# 0- ~4000                  840  1823
# 1- 4000~8000             1115  2539
# 2- 8000~12000             820  2051
# 3- 12000~17000            515  1333
# 4- 17000~25000            610  1674
# 5- 25000~35000            332  1062
# 6- 35000~50000            378  1246
# 7- 50000~75000            176   678
# 8- 75000~                 183   621
# {'-99': -0.2355, '0- ~4000': -0.1777, '1- 4000~8000': -0.1296, '2- 8000~12000': -0.0357, '3- 12000~17000': -0.0015, '4- 17000~25000': 0.057, '5- 25000~35000': 0.2103, '6- 35000~50000': 0.2403, '7- 50000~75000': 0.3962, '8- 75000~': 0.2693}
# card_award_new
# classification   bad  good
# card_award_new
# -99              269   547
# 0- ~4000         603  1254
# 1- 4000~8000     930  2154
# 2- 8000~12000    919  2187
# 3- 12000~17000   564  1512
# 4- 17000~25000   701  2005
# 5- 25000~35000   450  1265
# 6- 35000~50000   375  1187
# 7- 50000~75000   170   542
# 8- 75000~100000  147   534
# 9- 100000~       110   391
# {'-99': -0.2428, '0- ~4000': -0.2203, '1- 4000~8000': -0.1126, '2- 8000~12000': -0.0855, '3- 12000~17000': 0.0336, '4- 17000~25000': 0.0984, '5- 25000~35000': 0.0811, '6- 35000~50000': 0.1997, '7- 50000~75000': 0.207, '8- 75000~100000': 0.3375, '9- 100000~': 0.3157}
# card_award_highest
# classification       bad  good
# card_award_highest
# -99                  269   547
# 0- ~5000             260   418
# 1- 5000~10000        492   884
# 2- 10000~20000      1032  2080
# 3- 20000~30000       682  1769
# 4- 30000~45000       538  1418
# 5- 45000~75000       905  2761
# 6- 75000~100000      471  1445
# 7- 100000~150000     311  1038
# 8- 150000~200000     141   546
# 9- 200000~           137   672
# {'-99': -0.2428, '0- ~5000': -0.4777, '1- 5000~10000': -0.3665, '2- 10000~20000': -0.2516, '3- 20000~30000': 0.0006, '4- 30000~45000': 0.0166, '5- 45000~75000': 0.1629, '6- 75000~100000': 0.1685, '7- 100000~150000': 0.2527, '8- 150000~200000': 0.4013, '9- 200000~': 0.6378}
# card_award_highest_goodbank
# classification               bad  good
# card_award_highest_goodbank
# -99                          303   606
# 0- ~4000                     142   232
# 1- 4000~8000                 308   567
# 2- 8000~12000                512   873
# 3- 12000~17000               437   867
# 4- 17000~25000               733  1686
# 5- 25000~35000               597  1570
# 6- 35000~50000               678  1975
# 7- 50000~75000               527  1654
# 8- 75000~100000              453  1398
# 9- 100000~                   548  2150
# {'-99': -0.2594, '0- ~4000': -0.4616, '1- 4000~8000': -0.3423, '2- 8000~12000': -0.4189, '3- 12000~17000': -0.2674, '4- 17000~25000': -0.1195, '5- 25000~35000': 0.0144, '6- 35000~50000': 0.1167, '7- 50000~75000': 0.1912, '8- 75000~100000': 0.1744, '9- 100000~': 0.4144}
# card_award_used_highest
# classification           bad  good
# card_award_used_highest
# -99                      269   547
# 0- ~5000                 997  2272
# 1- 5000~8000             362   842
# 10- 130000~              225   934
# 2- 8000~10000            298   630
# 3- 10000~15000           587  1225
# 4- 15000~20000           504  1160
# 5- 20000~30000           637  1716
# 6- 30000~50000           629  1848
# 7- 50000~80000           410  1373
# 8- 80000~100000          180   522
# 9- 100000~130000         140   509
# {'-99': -0.2428, '0- ~5000': -0.1288, '1- 5000~8000': -0.1084, '10- 130000~': 0.4709, '2- 8000~10000': -0.2039, '3- 10000~15000': -0.2168, '4- 15000~20000': -0.1189, '5- 20000~30000': 0.0385, '6- 30000~50000': 0.1252, '7- 50000~80000': 0.2561, '8- 80000~100000': 0.1122, '9- 100000~130000': 0.3383}
# card_award_ratio_highest
# classification             bad  good
# card_award_ratio_highest
# -99                        269   547
# 0- ~0.05                   581  1476
# 1- 0.05~0.16               308   995
# 2- 0.16~0.39               526  1332
# 3- 0.39~0.54               327   762
# 4- 0.54~0.63               148   480
# 5- 0.63~0.91               709  2034
# 6- 0.91~                  2370  5952
# {'-99': -0.2428, '0- ~0.05': -0.0202, '1- 0.05~0.16': 0.2201, '2- 0.16~0.39': -0.0234, '3- 0.39~0.54': -0.1065, '4- 0.54~0.63': 0.2241, '5- 0.63~0.91': 0.1014, '6- 0.91~': -0.0317}
# card_award_sum
# classification    bad  good
# card_award_sum
# -99               269   547
# 0- ~10000         398   633
# 1- 10000~20000    352   697
# 2- 20000~40000    621  1260
# 3- 40000~60000    504  1137
# 4- 60000~80000    416  1022
# 5- 80000~110000   535  1279
# 6- 110000~140000  396  1106
# 7- 140000~200000  576  1635
# 8- 200000~300000  531  1664
# 9- 300000~        640  2598
# {'-99': -0.2428, '0- ~10000': -0.4885, '1- 10000~20000': -0.2694, '2- 20000~40000': -0.245, '3- 40000~60000': -0.1389, '4- 60000~80000': -0.0537, '5- 80000~110000': -0.0809, '6- 110000~140000': 0.0746, '7- 140000~200000': 0.0908, '8- 200000~300000': 0.1897, '9- 300000~': 0.4485}
# card_award_used
# classification    bad  good
# card_award_used
# -99               269   547
# 0- ~10000         702  1329
# 1- 10000~20000    468   983
# 2- 20000~40000    748  1687
# 3- 40000~60000    588  1437
# 4- 60000~80000    484  1226
# 5- 80000~110000   540  1454
# 6- 110000~140000  380  1085
# 7- 140000~200000  477  1476
# 8- 200000~300000  344  1260
# 9- 300000~        238  1094
# {'-99': -0.2428, '0- ~10000': -0.3143, '1- 10000~20000': -0.2104, '2- 20000~40000': -0.1392, '3- 40000~60000': -0.0589, '4- 60000~80000': -0.0231, '5- 80000~110000': 0.038, '6- 110000~140000': 0.0967, '7- 140000~200000': 0.1771, '8- 200000~300000': 0.3457, '9- 300000~': 0.5728}
# card_award_used_ratio
# classification          bad  good
# card_award_used_ratio
# -99                     269   547
# 0- ~0                   137   294
# 1- 0~0.15               171   416
# 2- 0.15~0.4             559  1728
# 3- 0.4~0.6              998  2868
# 4- 0.6~0.8             1269  3516
# 5- 0.8~1               1556  3537
# 6- 1~                   279   672
# {'-99': -0.2428, '0- ~0': -0.1889, '1- 0~0.15': -0.0635, '2- 0.15~0.4': 0.1761, '3- 0.4~0.6': 0.1031, '4- 0.6~0.8': 0.0666, '5- 0.8~1': -0.1314, '6- 1~': -0.0735}
# card_exceeding_count_
# classification            bad    good
# card_exceeding_count_
# -99                       NaN     2.0
# 0- ~0                  2652.0  6806.0
# 1- 0~1                 1394.0  3616.0
# 2- 1~2                  672.0  1727.0
# 3- 2~3                  303.0   814.0
# 4- 3~                   217.0   613.0
# {'-99': 0.0, '0- ~0': -0.01, '1- 0~1': 0.0007, '2- 1~2': -0.0086, '3- 2~3': 0.0357, '4- 3~': 0.086}
# card_exceeding_count_ratio
# classification                 bad    good
# card_exceeding_count_ratio
# -99                            NaN     2.0
# 0- ~0                       2652.0  6806.0
# 1- 0~0.1                     245.0   867.0
# 2- 0.1~0.3                  1368.0  3723.0
# 3- 0.3~0.5                   729.0  1636.0
# 4- 0.5~                      244.0   544.0
# {'-99': 0.0, '0- ~0': -0.01, '1- 0~0.1': 0.3113, '2- 0.1~0.3': 0.0487, '3- 0.3~0.5': -0.1442, '4- 0.5~': -0.1507}
# card_exceeding_money_sum
# classification               bad    good
# card_exceeding_money_sum
# -99                          NaN     2.0
# 0- ~0                     2652.0  6806.0
# 1- 0~3000                 1722.0  4133.0
# 2- 3000~7800               431.0  1140.0
# 3- 7800~12000              139.0   444.0
# 4- 12000~                  294.0  1053.0
# {'-99': 0.0, '0- ~0': -0.01, '1- 0~3000': -0.077, '2- 3000~7800': 0.0202, '3- 7800~12000': 0.2088, '4- 12000~': 0.3233}
# card_exceeding_money_max
# classification               bad    good
# card_exceeding_money_max
# -99                          NaN     2.0
# 0- ~0                     2652.0  6806.0
# 1- 0~4000                 1934.0  4596.0
# 2- 4000~9700               330.0  1036.0
# 3- 9700~15000              112.0   362.0
# 4- 15000~                  210.0   776.0
# {'-99': 0.0, '0- ~0': -0.01, '1- 0~4000': -0.0869, '2- 4000~9700': 0.1915, '3- 9700~15000': 0.2206, '4- 15000~': 0.3545}
# card_overdue_count
# classification       bad   good
# card_overdue_count
# -99                   15    126
# 0- ~0               4954  12930
# 1- 0~1               236    480
# 2- 1~                 33     42
# {'-99': 1.1757, '0- ~0': 0.0068, '1- 0~1': -0.2426, '2- 1~': -0.7113}
# card_overdue_money_sum
# classification             bad     good
# card_overdue_money_sum
# -99                        NaN      2.0
# 0- ~0                   4969.0  13054.0
# 1- 0~82                   33.0     94.0
# 2- 82~                   236.0    428.0
# {'-99': 0.0, '0- ~0': 0.0134, '1- 0~82': 0.0943, '2- 82~': -0.3572}
# card_overdue_money_max
# classification             bad     good
# card_overdue_money_max
# -99                        NaN      2.0
# 0- ~0                   4969.0  13054.0
# 1- 0~82                   33.0     95.0
# 2- 82~                   236.0    427.0
# {'-99': 0.0, '0- ~0': 0.0134, '1- 0~82': 0.1049, '2- 82~': -0.3596}
# card_overdue_months_in_5y
# classification                bad    good
# card_overdue_months_in_5y
# -99                           NaN     2.0
# 0- ~0                      2766.0  8688.0
# 1- 0~4                     1353.0  2550.0
# 2- 4~7                      386.0   771.0
# 3- 7~13                     332.0   654.0
# 4- 13~16                    109.0   214.0
# 5- 16~20                     95.0   200.0
# 6- 20~31                    133.0   292.0
# 7- 31~                       64.0   207.0
# {'-99': 0.0, '0- ~0': 0.192, '1- 0~4': -0.3187, '2- 4~7': -0.2607, '3- 7~13': -0.2745, '4- 13~16': -0.2779, '5- 16~20': -0.2081, '6- 20~31': -0.1661, '7- 31~': 0.2213}
# card_overdue_months_in_2y
# classification              bad   good
# card_overdue_months_in_2y
# -99                           2      9
# 0- ~0                      4191  11919
# 1- 0~1                      517    870
# 2- 1~2                      189    342
# 3- 2~5                      248    322
# 4- 5~                        91    116
# {'-99': 0.5516, '0- ~0': 0.0927, '1- 0~1': -0.4321, '2- 1~2': -0.3594, '3- 2~5': -0.6914, '4- 5~': -0.7098}
# card_overdue_months_in_1y
# classification              bad   good
# card_overdue_months_in_1y
# -99                           3     24
# 0- ~0                      4771  12870
# 1- 0~1                      301    475
# 2- 1~                       163    209
# {'-99': 1.1269, '0- ~0': 0.0398, '1- 0~1': -0.4963, '2- 1~': -0.7039}
# card_overdue_over90_in_5y
# classification                bad     good
# card_overdue_over90_in_5y
# -99                           NaN      2.0
# 0- ~0                      5118.0  13276.0
# 1- 0~1                       53.0    115.0
# 2- 1~                        67.0    185.0
# {'-99': 0.0, '0- ~0': 0.0007, '1- 0~1': -0.1779, '2- 1~': 0.0632}
# card_overdue_over90_in_2y
# classification              bad   good
# card_overdue_over90_in_2y
# -99                           2      9
# 0- ~0                      5232  13561
# 1- 0~                         4      8
# {'-99': 0.5516, '0- ~0': -0.0001, '1- 0~': -0.2594}
# card_overdue_over90_in_1y
# classification                bad     good
# card_overdue_over90_in_1y
# -99                           3.0     24.0
# 0- ~0                      5234.0  13553.0
# 1- 0~1                        NaN      1.0
# 2- 1~                         1.0      NaN
# {'-99': 1.1269, '0- ~0': -0.0011, '1- 0~1': 0.0, '2- 1~': 0.0}
# card_overdue_highest
# classification           bad    good
# card_overdue_highest
# -99                      NaN     2.0
# 0- ~0                 2766.0  8688.0
# 1- 0~5                2472.0  4888.0
# {'-99': 0.0, '0- ~0': 0.192, '1- 0~5': -0.2708}
# card_overdue_ratio
# classification         bad    good
# card_overdue_ratio
# -99                    NaN     2.0
# 0- ~0               3053.0  9424.0
# 1- 0~0.01            590.0  1299.0
# 2- 0.01~0.05         889.0  1587.0
# 3- 0.05~0.06          96.0   186.0
# 4- 0.06~0.1          254.0   472.0
# 5- 0.1~0.16          185.0   334.0
# 6- 0.16~0.34         155.0   243.0
# 7- 0.34~              16.0    31.0
# {'-99': 0.0, '0- ~0': 0.1746, '1- 0~0.01': -0.1633, '2- 0.01~0.05': -0.373, '3- 0.05~0.06': -0.2911, '4- 0.06~0.1': -0.3329, '5- 0.1~0.16': -0.3617, '6- 0.16~0.34': -0.5029, '7- 0.34~': -0.2911}
# card_overdue_10
# classification    bad   good
# card_overdue_10
# -99                15    112
# 0- ~0            3977  11225
# 1- 0~1            734   1299
# 2- 1~2            271    515
# 3- 2~             241    427
# {'-99': 1.0579, '0- ~0': 0.0851, '1- 0~1': -0.3817, '2- 1~2': -0.3105, '3- 2~': -0.3805}
# card_overdue_20
# classification    bad   good
# card_overdue_20
# -99                15    122
# 0- ~0            4615  12370
# 1- 0~1            461    800
# 2- 1~             147    286
# {'-99': 1.1435, '0- ~0': 0.0335, '1- 0~1': -0.4013, '2- 1~': -0.287}
# card_overdue_30
# classification    bad   good
# card_overdue_30
# -99                16    127
# 0- ~0            4930  12984
# 1- 0~             292    467
# {'-99': 1.1191, '0- ~0': 0.0159, '1- 0~': -0.4829}
# card_overdue_10_extend_1y
# classification              bad   good
# card_overdue_10_extend_1y
# -99                          16    124
# 0- ~0                      4784  12815
# 1- 0~1                      347    540
# 2- 1~                        91     99
# {'-99': 1.0952, '0- ~0': 0.0328, '1- 0~1': -0.5103, '2- 1~': -0.8683}
# card_overdue_20_extend_1y
# classification              bad   good
# card_overdue_20_extend_1y
# -99                          16    125
# 0- ~0                      4982  13109
# 1- 0~                       240    344
# {'-99': 1.1032, '0- ~0': 0.015, '1- 0~': -0.5925}
# card_overdue_30_extend_1y
# classification              bad   good
# card_overdue_30_extend_1y
# -99                          16    128
# 0- ~0                      5095  13290
# 1- 0~                       127    160
# {'-99': 1.1269, '0- ~0': 0.0062, '1- 0~': -0.7215}
# card_overdue_10_extend_2y
# classification              bad   good
# card_overdue_10_extend_2y
# -99                          16    122
# 0- ~0                      4538  12445
# 1- 0~1                      493    782
# 2- 1~2                      130    172
# 3- 2~                        61     57
# {'-99': 1.0789, '0- ~0': 0.0563, '1- 0~1': -0.4912, '2- 1~2': -0.6726, '3- 2~': -1.0203}
# card_overdue_20_extend_2y
# classification              bad   good
# card_overdue_20_extend_2y
# -99                          15    124
# 0- ~0                      4803  12863
# 1- 0~1                      356    498
# 2- 1~                        64     93
# {'-99': 1.1597, '0- ~0': 0.0326, '1- 0~1': -0.6168, '2- 1~': -0.5788}
# card_overdue_30_extend_2y
# classification              bad   good
# card_overdue_30_extend_2y
# -99                          16    127
# 0- ~0                      5011  13181
# 1- 0~1                      193    246
# 2- 1~                        18     24
# {'-99': 1.1191, '0- ~0': 0.0146, '1- 0~1': -0.7099, '2- 1~': -0.6648}
# card_decrease
# classification   bad   good
# card_decrease
# -99               13     93
# 0- ~0           4163  10694
# 1- 0~1           885   2298
# 2- 1~            177    493
# {'-99': 1.0151, '0- ~0': -0.0091, '1- 0~1': 0.0017, '2- 1~': 0.0718}
# card_freeze
# classification   bad   good
# card_freeze
# -99               17    129
# 0- ~0           5219  13448
# 1- 0~              2      1
# {'-99': 1.0741, '0- ~0': -0.006, '1- 0~': -1.6457}
# card_doubtful
# classification     bad     good
# card_doubtful
# -99               17.0    129.0
# 0- ~0           5220.0  13449.0
# 1- 0~              1.0      NaN
# {'-99': 1.0741, '0- ~0': -0.0061, '1- 0~': 0.0}
# card_unactivated
# classification     bad  good
# card_unactivated
# -99                 10    64
# 0- ~0             3432  8044
# 1- 0~1            1283  3523
# 2- 1~3             473  1694
# 3- 3~               40   253
# {'-99': 0.9038, '0- ~0': -0.1007, '1- 0~1': 0.0576, '2- 1~3': 0.3232, '3- 3~': 0.892}
# loan_total_account
# classification         bad    good
# loan_total_account
# -99                    NaN     3.0
# 0- ~0                426.0  2418.0
# 1- 0~1               543.0   885.0
# 2- 1~3              1051.0  2091.0
# 3- 3~12             2500.0  5701.0
# 4- 12~17             378.0  1025.0
# 5- 17~29             248.0   915.0
# 6- 29~                92.0   540.0
# {'-99': 0.0, '0- ~0': 0.7837, '1- 0~1': -0.464, '2- 1~3': -0.2646, '3- 3~12': -0.1282, '4- 12~17': 0.045, '5- 17~29': 0.353, '6- 29~': 0.8173}
# loan_notsettled_account
# classification              bad    good
# loan_notsettled_account
# -99                         NaN    10.0
# 0- ~0                     636.0  2798.0
# 1- 0~1                    817.0  1592.0
# 2- 1~4                   1930.0  4537.0
# 3- 4~7                   1036.0  2440.0
# 4- 7~9                    348.0   826.0
# 5- 9~11                   174.0   445.0
# 6- 11~17                  206.0   632.0
# 7- 17~                     91.0   298.0
# {'-99': 0.0, '0- ~0': 0.529, '1- 0~1': -0.2854, '2- 1~4': -0.0978, '3- 4~7': -0.0959, '4- 7~9': -0.0881, '5- 9~11': -0.0135, '6- 11~17': 0.1685, '7- 17~': 0.2337}
# loan_settle_account
# classification        bad  good
# loan_settle_account
# -99                     2    14
# 0- ~0                1713  4796
# 1- 0~2               1840  3764
# 2- 2~4                840  1972
# 3- 4~8                592  1579
# 4- 8~12               139   546
# 5- 12~15               36   236
# 6- 15~                 76   671
# {'-99': 0.9934, '0- ~0': 0.077, '1- 0~2': -0.2368, '2- 2~4': -0.0991, '3- 4~8': 0.0285, '4- 8~12': 0.4156, '5- 12~15': 0.9278, '6- 15~': 1.2255}
# loan_settle_past6m
# classification       bad  good
# loan_settle_past6m
# -99                    6    45
# 0- ~0               3029  8076
# 1- 0~1              1120  2442
# 2- 1~4               809  2002
# 3- 4~8               219   640
# 4- 8~                 55   373
# {'-99': 1.0624, '0- ~0': 0.0282, '1- 0~1': -0.173, '2- 1~4': -0.0464, '3- 4~8': 0.1199, '4- 8~': 0.9617}
# loan_settle_past3m
# classification       bad  good
# loan_settle_past3m
# -99                   13    72
# 0- ~0               3762  9937
# 1- 0~2              1180  2737
# 2- 2~4               221   494
# 3- 4~                 62   338
# {'-99': 0.7592, '0- ~0': 0.0188, '1- 0~2': -0.1112, '2- 2~4': -0.1481, '3- 4~': 0.7434}
# loan_settle_past1m
# classification       bad   good
# loan_settle_past1m
# -99                   15    127
# 0- ~0               5054  12978
# 1- 0~1               143    283
# 2- 1~                 26    190
# {'-99': 1.1836, '0- ~0': -0.0094, '1- 0~1': -0.2699, '2- 1~': 1.0364}
# loan_settle_past6m_ratio
# classification             bad  good
# loan_settle_past6m_ratio
# -99                          6    45
# 0- ~0                     3029  8076
# 1- 0~0.1                   313   895
# 2- 0.1~0.2                 798  2045
# 3- 0.2~0.4                 802  1816
# 4- 0.4~                    290   701
# {'-99': 1.0624, '0- ~0': 0.0282, '1- 0~0.1': 0.0981, '2- 0.1~0.2': -0.0115, '3- 0.2~0.4': -0.1352, '4- 0.4~': -0.0699}
# loan_settle_past3m_ratio
# classification             bad  good
# loan_settle_past3m_ratio
# -99                         13    72
# 0- ~0                     3762  9937
# 1- 0~                     1463  3569
# {'-99': 0.7592, '0- ~0': 0.0188, '1- 0~': -0.0607}
# loan_settle_past1m_ratio
# classification             bad   good
# loan_settle_past1m_ratio
# -99                         15    127
# 0- ~0                     5054  12978
# 1- 0~                      169    473
# {'-99': 1.1836, '0- ~0': -0.0094, '1- 0~': 0.0767}
# loan_settle_next1m
# classification       bad   good
# loan_settle_next1m
# -99                   17    129
# 0- ~0               5221  13449
# {'-99': 1.0741, '0- ~0': -0.0063}
# loan_settle_next3m
# classification         bad     good
# loan_settle_next3m
# -99                   11.0     85.0
# 0- ~0               4006.0  10365.0
# 1- 0~2              1046.0   2570.0
# 2- 2~3                95.0    287.0
# 3- 3~7                74.0    246.0
# 4- 7~8                 4.0     10.0
# 5- 8~9                 2.0      5.0
# 6- 9~10                NaN      5.0
# 8- 11~13               NaN      2.0
# 9- 13~                 NaN      3.0
# {'-99': 1.0922, '0- ~0': -0.0019, '1- 0~2': -0.0536, '2- 2~3': 0.1531, '3- 3~7': 0.2488, '4- 7~8': -0.0362, '5- 8~9': -0.0362, '6- 9~10': 0.0, '8- 11~13': 0.0, '9- 13~': 0.0}
# loan_settle_next6m
# classification       bad  good
# loan_settle_next6m
# -99                    9    56
# 0- ~0               3043  8053
# 1- 0~3              1863  4487
# 2- 3~4               128   331
# 3- 4~8               172   496
# 4- 8~                 23   155
# {'-99': 0.8756, '0- ~0': 0.0207, '1- 0~3': -0.0735, '2- 3~4': -0.0024, '3- 4~8': 0.1066, '4- 8~': 0.9554}
# loan_settle_next12m
# classification        bad  good
# loan_settle_next12m
# -99                     5    31
# 0- ~0                1847  5293
# 1- 0~3               2421  5630
# 2- 3~5                500  1241
# 3- 5~6                131   342
# 4- 6~13               287   841
# 5- 13~                 47   200
# {'-99': 0.872, '0- ~0': 0.1003, '1- 0~3': -0.1086, '2- 3~5': -0.0434, '3- 5~6': 0.0071, '4- 6~13': 0.1226, '5- 13~': 0.4957}
# loan_award_past6m
# classification        bad    good
# loan_award_past6m
# -99                   NaN     3.0
# 0- ~0               643.0  2836.0
# 1- 0~1000            85.0   144.0
# 2- 1000~5000        436.0   793.0
# 3- 5000~10000       465.0   847.0
# 4- 10000~          3609.0  8955.0
# {'-99': 0.0, '0- ~0': 0.5315, '1- 0~1000': -0.4253, '2- 1000~5000': -0.3543, '3- 5000~10000': -0.3528, '4- 10000~': -0.0437}
# loan_award_past3m
# classification        bad    good
# loan_award_past3m
# -99                   NaN     3.0
# 0- ~0               658.0  2861.0
# 1- 0~20000         2553.0  5296.0
# 2- 20000~40000      994.0  2446.0
# 3- 40000~70000      583.0  1406.0
# 4- 70000~100000     199.0   655.0
# 5- 100000~150000    135.0   459.0
# 6- 150000~200000     40.0   181.0
# 7- 200000~           76.0   271.0
# {'-99': 0.0, '0- ~0': 0.5172, '1- 0~20000': -0.2228, '2- 20000~40000': -0.052, '3- 40000~70000': -0.0722, '4- 70000~100000': 0.2388, '5- 100000~150000': 0.2713, '6- 150000~200000': 0.5571, '7- 200000~': 0.3189}
# loan_award_past1m
# classification        bad    good
# loan_award_past1m
# -99                   NaN     3.0
# 0- ~0               692.0  2891.0
# 1- 0~2000           910.0  1758.0
# 2- 2000~8000       1879.0  4120.0
# 3- 8000~16000       928.0  2298.0
# 4- 16000~22000      325.0   815.0
# 5- 22000~28000      146.0   447.0
# 6- 28000~36000      127.0   416.0
# 7- 36000~           231.0   830.0
# {'-99': 0.0, '0- ~0': 0.4773, '1- 0~2000': -0.294, '2- 2000~8000': -0.1674, '3- 8000~16000': -0.0457, '4- 16000~22000': -0.0331, '5- 22000~28000': 0.1664, '6- 28000~36000': 0.234, '7- 36000~': 0.3265}
# loan_award_next1m
# classification        bad    good
# loan_award_next1m
# -99                   NaN     3.0
# 0- ~0               995.0  3557.0
# 1- 0~600            350.0   575.0
# 2- 600~2100         860.0  1734.0
# 3- 2100~3900        790.0  1726.0
# 4- 3900~           2243.0  5983.0
# {'-99': 0.0, '0- ~0': 0.3214, '1- 0~600': -0.4561, '2- 600~2100': -0.2513, '3- 2100~3900': -0.171, '4- 3900~': 0.0286}
# loan_award_next3m
# classification        bad    good
# loan_award_next3m
# -99                   NaN     3.0
# 0- ~2100           1402.0  4219.0
# 1- 2100~5000        580.0  1176.0
# 2- 5000~9900        817.0  1684.0
# 3- 9900~20000       978.0  2374.0
# 4- 20000~59000     1058.0  2829.0
# 5- 59000~           403.0  1293.0
# {'-99': 0.0, '0- ~2100': 0.1492, '1- 2100~5000': -0.2457, '2- 5000~9900': -0.2292, '3- 9900~20000': -0.0657, '4- 20000~59000': 0.031, '5- 59000~': 0.2133}
# loan_award_next6m
# classification        bad    good
# loan_award_next6m
# -99                   NaN     3.0
# 0- ~5800           1559.0  4529.0
# 1- 5800~14000       791.0  1567.0
# 2- 14000~19000      370.0   821.0
# 3- 19000~26000      418.0  1037.0
# 4- 26000~35000      410.0   927.0
# 5- 35000~67000      779.0  1997.0
# 6- 67000~92000      282.0   746.0
# 7- 92000~120000     188.0   511.0
# 8- 120000~210000    247.0   708.0
# 9- 210000~          194.0   732.0
# {'-99': 0.0, '0- ~5800': 0.1139, '1- 5800~14000': -0.2689, '2- 14000~19000': -0.1555, '3- 19000~26000': -0.0439, '4- 26000~35000': -0.1367, '5- 35000~67000': -0.0111, '6- 67000~92000': 0.0203, '7- 92000~120000': 0.0474, '8- 120000~210000': 0.1005, '9- 210000~': 0.3754}
# loan_award_next12m
# classification         bad    good
# loan_award_next12m
# -99                    NaN     3.0
# 0- ~3000            1084.0  3544.0
# 1- 3000~23000       1088.0  2248.0
# 2- 23000~41000       654.0  1550.0
# 3- 41000~53000       344.0   812.0
# 4- 53000~76000       469.0  1121.0
# 5- 76000~100000      361.0   831.0
# 6- 100000~150000     463.0  1177.0
# 7- 150000~250000     395.0  1040.0
# 8- 250000~470000     252.0   758.0
# 9- 470000~           128.0   494.0
# {'-99': 0.0, '0- ~3000': 0.2321, '1- 3000~23000': -0.2268, '2- 23000~41000': -0.0896, '3- 41000~53000': -0.0937, '4- 53000~76000': -0.0811, '5- 76000~100000': -0.1188, '6- 100000~150000': -0.0195, '7- 150000~250000': 0.0156, '8- 250000~470000': 0.1487, '9- 470000~': 0.398}
# loan_moneymonthly_next3m
# classification              bad    good
# loan_moneymonthly_next3m
# -99                         NaN     3.0
# 0- ~0                     969.0  3499.0
# 1- 0~1600                 962.0  1817.0
# 2- 1600~3300              868.0  1763.0
# 3- 3300~6300              907.0  2170.0
# 4- 6300~14000             880.0  2388.0
# 5- 14000~24000            352.0   909.0
# 6- 24000~                 300.0  1029.0
# {'-99': 0.0, '0- ~0': 0.3315, '1- 0~1600': -0.3166, '2- 1600~3300': -0.2439, '3- 3300~6300': -0.0802, '4- 6300~14000': 0.0458, '5- 14000~24000': -0.0038, '6- 24000~': 0.28}
# loan_moneymonthly_next6m
# classification               bad    good
# loan_moneymonthly_next6m
# -99                          NaN     3.0
# 0- ~2800                  2554.0  6575.0
# 1- 2800~4900               776.0  1761.0
# 2- 4900~9200               776.0  1996.0
# 3- 9200~20000              691.0  1803.0
# 4- 20000~29000             186.0   493.0
# 5- 29000~61000             179.0   630.0
# 6- 61000~                   76.0   317.0
# {'-99': 0.0, '0- ~2800': -0.0069, '1- 2800~4900': -0.133, '2- 4900~9200': -0.0078, '3- 9200~20000': 0.0066, '4- 20000~29000': 0.0223, '5- 29000~61000': 0.3058, '6- 61000~': 0.4757}
# loan_moneymonthly_next12m
# classification                bad    good
# loan_moneymonthly_next12m
# -99                           NaN     3.0
# 0- ~100                     926.0  3329.0
# 1- 100~2900                1698.0  3511.0
# 2- 2900~8700               1425.0  3415.0
# 3- 8700~13000               456.0  1117.0
# 4- 13000~21000              359.0   960.0
# 5- 21000~                   374.0  1243.0
# {'-99': 0.0, '0- ~100': 0.327, '1- 100~2900': -0.2261, '2- 2900~8700': -0.0785, '3- 8700~13000': -0.0566, '4- 13000~21000': 0.0311, '5- 21000~': 0.2485}
# loan_count_bank
# classification    bad  good
# loan_count_bank
# -99                 9    68
# 0- ~0            3364  9353
# 1- 0~1           1081  2141
# 2- 1~3            600  1361
# 3- 3~7            144   492
# 4- 7~11            24   101
# 5- 11~             16    62
# {'-99': 1.0698, '0- ~0': 0.0701, '1- 0~1': -0.2691, '2- 1~3': -0.1335, '3- 3~7': 0.2762, '4- 7~11': 0.4846, '5- 11~': 0.402}
# loan_ratio_bank
# classification                bad  good
# loan_ratio_bank
# -99                             9    68
# 0- ~0                        3364  9353
# 1- 0~0.1                      152   498
# 2- 0.1~0.22                   432   908
# 3- 0.22~0.35000000000000003   427   963
# 4- 0.35000000000000003~0.44   105   260
# 5- 0.44~0.55                  295   617
# 6- 0.55~0.65                   40   123
# 7- 0.65~0.86                  124   300
# 8- 0.86~0.99                    6    20
# 9- 0.99~                      284   468
# {'-99': 1.0698, '0- ~0': 0.0701, '1- 0~0.1': 0.2342, '2- 0.1~0.22': -0.2097, '3- 0.22~0.35000000000000003': -0.1392, '4- 0.35000000000000003~0.44': -0.0458, '5- 0.44~0.55': -0.2146, '6- 0.55~0.65': 0.1708, '7- 0.65~0.86': -0.069, '8- 0.86~0.99': 0.2515, '9- 0.99~': -0.453}
# loan_count_bank_country_stock
# classification                  bad  good
# loan_count_bank_country_stock
# -99                              10    69
# 0- ~0                          3625  9809
# 1- 0~1                          967  2095
# 2- 1~3                          502  1171
# 3- 3~5                           87   258
# 4- 5~9                           30   109
# 5- 9~                            17    67
# {'-99': 0.979, '0- ~0': 0.0429, '1- 0~1': -0.1794, '2- 1~3': -0.1055, '3- 3~5': 0.1345, '4- 5~9': 0.3376, '5- 9~': 0.419}
# loan_ratio_bank_country_stock
# classification                  bad  good
# loan_ratio_bank_country_stock
# -99                              10    69
# 0- ~0                          3625  9809
# 1- 0~0.05                        26   128
# 2- 0.05~0.14                    242   617
# 3- 0.14~0.17                     74   185
# 4- 0.17~0.25                    294   647
# 5- 0.25~0.41000000000000003     295   644
# 6- 0.41000000000000003~0.61     300   740
# 7- 0.61~0.77                     93   243
# 8- 0.77~0.9                      19    50
# 9- 0.9~                         260   446
# {'-99': 0.979, '0- ~0': 0.0429, '1- 0~0.05': 0.6414, '2- 0.05~0.14': -0.0166, '3- 0.14~0.17': -0.0362, '4- 0.17~0.25': -0.1637, '5- 0.25~0.41000000000000003': -0.1718, '6- 0.41000000000000003~0.61': -0.0496, '7- 0.61~0.77': 0.008, '8- 0.77~0.9': 0.0151, '9- 0.9~': -0.4129}
# loan_count_bank_commerce
# classification             bad   good
# loan_count_bank_commerce
# -99                         11     81
# 0- ~0                     3842  10052
# 1- 0~2                    1117   2393
# 2- 2~6                     199    720
# 3- 6~                       69    332
# {'-99': 1.044, '0- ~0': 0.0093, '1- 0~2': -0.1906, '2- 2~6': 0.3334, '3- 6~': 0.6185}
# loan_ratio_bank_commerce
# classification             bad   good
# loan_ratio_bank_commerce
# -99                         11     81
# 0- ~0.1                   3983  10411
# 1- 0.1~0.3                 628   1410
# 2- 0.3~0.5                 414   1134
# 3- 0.5~                    202    542
# {'-99': 1.044, '0- ~0.1': 0.0083, '1- 0.1~0.3': -0.1437, '2- 0.3~0.5': 0.0551, '3- 0.5~': 0.0345}
# loan_count_bank_village
# classification            bad   good
# loan_count_bank_village
# -99                        17    124
# 0- ~0                    5176  13355
# 1- 0~1                     44     87
# 2- 1~                       1     12
# {'-99': 1.0346, '0- ~0': -0.0047, '1- 0~1': -0.2708, '2- 1~': 1.5324}
# loan_ratio_bank_village
# classification            bad   good
# loan_ratio_bank_village
# -99                        17    124
# 0- ~0                    5176  13355
# 1- 0~                      45     99
# {'-99': 1.0346, '0- ~0': -0.0047, '1- 0~': -0.1641}
# loan_count_bank_rcu_commerce
# classification                 bad   good
# loan_count_bank_rcu_commerce
# -99                             12    106
# 0- ~0                         4137  11403
# 1- 0~1                         629   1291
# 2- 1~3                         307    512
# 3- 3~                          153    266
# {'-99': 1.226, '0- ~0': 0.0614, '1- 0~1': -0.2335, '2- 1~3': -0.441, '3- 3~': -0.3995}
# loan_ratio_bank_rcu_commerce
# classification                 bad   good
# loan_ratio_bank_rcu_commerce
# -99                             12    106
# 0- ~0                         4137  11403
# 1- 0~0.15                      235    620
# 2- 0.15~0.3                    360    587
# 3- 0.3~0.45                    219    312
# 4- 0.45~0.6                    152    284
# 5- 0.6~                        123    266
# {'-99': 1.226, '0- ~0': 0.0614, '1- 0~0.15': 0.0176, '2- 0.15~0.3': -0.4636, '3- 0.3~0.45': -0.5986, '4- 0.45~0.6': -0.3274, '5- 0.6~': -0.1812}
# loan_count_bank_foreign
# classification            bad   good
# loan_count_bank_foreign
# -99                        17    128
# 0- ~0                    5190  13394
# 1- 0~                      31     56
# {'-99': 1.0663, '0- ~0': -0.0044, '1- 0~': -0.3611}
# loan_ratio_bank_foreign
# classification            bad   good
# loan_ratio_bank_foreign
# -99                        17    128
# 0- ~0                    5190  13394
# 1- 0~                      31     56
# {'-99': 1.0663, '0- ~0': -0.0044, '1- 0~': -0.3611}
# loan_count_mcc
# classification   bad  good
# loan_count_mcc
# -99                8    85
# 0- ~0           3412  9747
# 1- 0~2          1673  3301
# 2- 2~3            96   216
# 3- 3~5            39   136
# 4- 5~             10    93
# {'-99': 1.4107, '0- ~0': 0.0971, '1- 0~2': -0.2729, '2- 2~3': -0.1416, '3- 3~5': 0.2966, '4- 5~': 1.2775}
# loan_ratio_mcc
# classification   bad  good
# loan_ratio_mcc
# -99                8    85
# 0- ~0           3412  9747
# 1- 0~0.05         40   180
# 2- 0.05~0.1      216   507
# 3- 0.1~0.14      244   530
# 4- 0.14~0.26     567  1075
# 5- 0.26~0.32      38   106
# 6- 0.32~0.45     278   546
# 7- 0.45~0.6      240   454
# 8- 0.6~          195   348
# {'-99': 1.4107, '0- ~0': 0.0971, '1- 0~0.05': 0.5516, '2- 0.05~0.1': -0.0993, '3- 0.1~0.14': -0.1768, '4- 0.14~0.26': -0.3128, '5- 0.26~0.32': 0.0733, '6- 0.32~0.45': -0.2775, '7- 0.45~0.6': -0.3151, '8- 0.6~': -0.3733}
# loan_count_cfc
# classification   bad  good
# loan_count_cfc
# -99                8    62
# 0- ~0           2708  8080
# ...
# {'-99': -0.1775, '0- ~0': 1.4921, '1- 0~5': 1.9579, '2- 5~10': 2.8486, '3- 10~20': 1.7274, '4- 20~': 2.0862}
# call_1w_b
# classification   bad   good
# call_1w_b
# -99             5106  11083
# 0- ~0             18    192
# 1- 0~5             5     96
# 2- 5~10            1     78
# 3- 10~20          17    235
# 4- 20~            91   1894
# {'-99': -0.1775, '0- ~0': 1.4146, '1- 0~5': 2.0024, '2- 5~10': 3.4042, '3- 10~20': 1.6739, '4- 20~': 2.0831}
# call_1w_n
# classification     bad     good
# call_1w_n
# -99             5120.0  11238.0
# 0- ~0             73.0   1617.0
# 1- 0~0.1          40.0    660.0
# 2- 0.1~0.2         5.0     48.0
# 3- 0.2~0.5         NaN     14.0
# 4- 0.5~            NaN      1.0
# {'-99': -0.1664, '0- ~0': 2.1454, '1- 0~0.1': 1.8508, '2- 0.1~0.2': 1.3093, '3- 0.2~0.5': 0.0, '4- 0.5~': 0.0}
# call_1m_diff
# classification   bad   good
# call_1m_diff
# -99             5108  11113
# 0- ~0             57   1051
# 1- 0~0.2          38    823
# 2- 0.2~0.5        13    311
# 3- 0.5~0.8         8     98
# 4- 0.8~           14    182
# {'-99': -0.1752, '0- ~0': 1.9619, '1- 0~0.2': 2.1229, '2- 0.2~0.5': 2.2223, '3- 0.5~0.8': 1.553, '4- 0.8~': 1.6124}
# call_1m_city_z
# classification   bad   good
# call_1m_city_z
# -99             5106  11083
# 0- ~0              6    115
# 1- 0~2            92   1665
# 2- 2~5            22    501
# 3- 5~10           10    164
# 4- 10~             2     50
# {'-99': -0.1775, '0- ~0': 2.0007, '1- 0~2': 1.9433, '2- 2~5': 2.1731, '3- 5~10': 1.8448, '4- 10~': 2.2664}
# call_address_city
# classification      bad   good
# call_address_city
# 万州                  NaN    1.0
# 上海                  5.0   72.0
# 东莞                  NaN    1.0
# 东营                  1.0   26.0
# 临夏                  NaN    4.0
# 临沂                  7.0   32.0
# 乐山                  NaN    1.0
# 保定                  NaN   26.0
# 兰州                  4.0   94.0
# 共和                  NaN    3.0
# 内江                  NaN    2.0
# 北京                  5.0  287.0
# 北海                  NaN    3.0
# 南京                  1.0   22.0
# 南宁                  3.0   76.0
# 南通                  1.0   28.0
# 台州                  1.0   31.0
# 合肥                  4.0   85.0
# 吴忠                  NaN    1.0
# 咸阳                  2.0   33.0
# 唐山                  NaN   23.0
# 商洛                  NaN    3.0
# 天津                  4.0   98.0
# 宁德                  NaN    1.0
# 宁波                  1.0   29.0
# 安庆                  NaN    2.0
# 安康                  1.0    5.0
# 安顺                  NaN    8.0
# 定西                  NaN    6.0
# 宝鸡                  3.0   35.0
# ...                 ...    ...
# 苏州                  2.0   34.0
# 荆州                  NaN    1.0
# 莱芜                  NaN    1.0
# 衢州                  NaN    1.0
# 襄阳                  4.0   28.0
# 西宁                  1.0   22.0
# 西安                 11.0  154.0
# 贵港                  NaN    3.0
# 贵阳                  2.0   46.0
# 资阳                  1.0    2.0
# 运城                  NaN    1.0
# 连云港                 NaN    1.0
# 遂宁                  NaN    1.0
# 遵义                  2.0    8.0
# 邵阳                  NaN    1.0
# 郑州                  7.0   83.0
# 都匀                  1.0    NaN
# 重庆                  2.0   69.0
# 金华                  NaN    2.0
# 钦州                  NaN    7.0
# 银川                  NaN    1.0
# 镇江                  1.0   33.0
# 长沙                  4.0  123.0
# 防城港                 NaN    6.0
# 雅安                  NaN    1.0
# 青岛                  1.0   23.0
# 马鞍山                 NaN    1.0
# 驻马店                 NaN    2.0
# 黄南                  NaN    1.0
# 黔江                  1.0    2.0
#
# [115 rows x 2 columns]
# {'万州': 0.0, '上海': 1.7147, '东莞': 0.0, '东营': 2.3056, '临夏': 0.0, '临沂': 0.5673, '乐山': 0.0, '保定': 0.0, '兰州': 2.2045, '共和': 0.0, '内江': 0.0, '北京': 3.0975, '北海': 0.0, '南京': 2.1385, '南宁': 2.2796, '南通': 2.3797, '台州': 2.4815, '合肥': 2.1038, '吴忠': 0.0, '咸阳': 1.8508, '唐山': 0.0, '商洛': 0.0, '天津': 2.2462, '宁德': 0.0, '宁波': 2.4148, '安庆': 0.0, '安康': 0.6569, '安顺': 0.0, '定西': 0.0, '宝鸡': 1.5042, '宣城': 0.0, '宿迁': 0.0, '崇左': 0.0, '常州': 0.0, '常德': 0.0, '广州': 0.4338, '廊坊': 0.0, '延安': 0.0, '开封': 0.0, '德阳': 0.0, '成都': 2.3868, '拉萨': 1.2447, '攀枝花': 0.0, '文山': 0.0, '新乡': 0.0, '无锡': 1.1757, '昆明': 3.5361, '曲靖': 0.0, '杭州': 3.0365, '柳州': 1.0624, '桂林': -0.9525, '武威': 0.0, '武汉': 0.0, '汉中': 0.0, '池州': 0.0, '沈阳': 0.0, '河池': 0.0, '泰安': 0.7703, '洛阳': 0.0, '济南': 2.5738, '济宁': 0.2515, '海东': 0.0, '海北': 0.0, '海南': 0.0, '海晏': 0.0, '涪陵': 0.9934, '淄博': 1.5598, '淮南': 0.0, '淮安': 0.0, '深圳': 0.6569, '渭南': 0.0, '湘潭': 0.0, '滨州': 1.3501, '潍坊': 1.4454, '烟台': 1.1269, '玉林': 2.183, '白银': -0.2594, '益阳': 0.0, '眉山': 0.0, '石嘴山': 0.0, '石家庄': 0.0, '绍兴': 0.0, '缺失': -0.1775, '舟山': 0.0, '芜湖': 0.0, '苏州': 1.8807, '荆州': 0.0, '莱芜': 0.0, '衢州': 0.0, '襄阳': 0.9934, '西宁': 2.1385, '西安': 1.6865, '贵港': 0.0, '贵阳': 2.183, '资阳': -0.2594, '运城': 0.0, '连云港': 0.0, '遂宁': 0.0, '遵义': 0.4338, '邵阳': 0.0, '郑州': 1.5204, '都匀': 0.0, '重庆': 2.5884, '金华': 0.0, '钦州': 0.0, '银川': 0.0, '镇江': 2.544, '长沙': 2.4734, '防城港': 0.0, '雅安': 0.0, '青岛': 2.183, '马鞍山': 0.0, '驻马店': 0.0, '黄南': 0.0, '黔江': -0.2594}
# call_address_pro
# classification       bad     good
# call_address_pro
# 上海                   5.0     72.0
# 云南                   1.0     93.0
# 北京                   5.0    287.0
# 四川                   7.0    151.0
# 天津                   4.0     98.0
# 宁夏                   NaN      3.0
# 安徽                   4.0     93.0
# 山东                  33.0    313.0
# 山西                   NaN      1.0
# 广东                   2.0     10.0
# 广西                   9.0    151.0
# 江苏                  10.0    211.0
# 河北                   NaN     98.0
# 河南                   7.0     88.0
# 浙江                   3.0    119.0
# 湖北                   4.0     30.0
# 湖南                   4.0    130.0
# 甘肃                   6.0    106.0
# 福建                   NaN      1.0
# 缺失                5106.0  11083.0
# 西藏                   1.0      9.0
# 贵州                   5.0     62.0
# 辽宁                   NaN      1.0
# 重庆                   4.0     79.0
# 陕西                  17.0    254.0
# 青海                   1.0     35.0
# {'上海': 1.7147, '云南': 3.5801, '北京': 3.0975, '四川': 2.1189, '天津': 2.2462, '宁夏': 0.0, '安徽': 2.1938, '山东': 1.2972, '山西': 0.0, '广东': 0.6569, '广西': 1.8675, '江苏': 2.0968, '河北': 0.0, '河南': 1.5789, '浙江': 2.728, '湖北': 1.0624, '湖南': 2.5287, '甘肃': 1.9192, '福建': 0.0, '缺失': -0.1775, '西藏': 1.2447, '贵州': 1.5652, '辽宁': 0.0, '重庆': 2.0306, '陕西': 1.7516, '青海': 2.6028}
# call_1m_city_b
# classification   bad   good
# call_1m_city_b
# -99             5106  11083
# 0- ~0             10    116
# 1- 0~2            78   1485
# 2- 2~5            26    499
# 3- 5~10           12    269
# 4- 10~             6    126
# {'-99': -0.1775, '0- ~0': 1.4985, '1- 0~2': 1.994, '2- 2~5': 2.002, '3- 5~10': 2.1573, '4- 10~': 2.092}
# city_match
# classification   bad   good
# city_match
# 0                637   2183
# 1               4601  11395
# {0: 0.2792, 1: -0.0456}
# presidence_match
# classification     bad  good
# presidence_match
# 0                 1730  4489
# 1                 3508  9089
# {0: 0.001, 1: -0.0005}
# company_match
# classification   bad   good
# company_match
# 0                630   2210
# 1               4608  11368
# {0: 0.3025, 1: -0.0495}
# house_match
# classification   bad   good
# house_match
# 0               3816  10840
# 1               1422   2738
# {0: 0.0915, 1: -0.2973}
# cus_age
# classification   bad  good
# cus_age
# 0- ~25           417   972
# 1- 25~30        1172  2959
# 2- 30~34         816  2261
# 3- 34~40        1120  2999
# 4- 40~45         767  1983
# 5- 45~50         566  1471
# 6- 50~           380   933
# {'0- ~25': -0.1062, '1- 25~30': -0.0264, '2- 30~34': 0.0666, '3- 34~40': 0.0324, '4- 40~45': -0.0026, '5- 45~50': 0.0026, '6- 50~': -0.0543}
# liushui_final
# classification     bad    good
# liushui_final
# -99.00          1500.0  7223.0
#  0.00             33.0    63.0
#  1.00              5.0     8.0
#  20.83             1.0     NaN
#  50.83             NaN     1.0
#  182.00            1.0     NaN
#  412.33            NaN     1.0
#  567.33            NaN     1.0
#  600.17            NaN     1.0
#  600.83            NaN     1.0
#  767.33            1.0     NaN
#  850.48            NaN     1.0
#  966.83            1.0     NaN
#  1077.35           NaN     1.0
#  1106.00           NaN     1.0
#  1114.49           NaN     1.0
#  1127.67           NaN     1.0
#  1170.08           NaN     1.0
#  1171.50           NaN     1.0
#  1234.00           NaN     1.0
#  1245.00           1.0     NaN
#  1304.02           NaN     1.0
#  1320.02           1.0     NaN
#  1348.33           1.0     NaN
#  1355.00           1.0     NaN
#  1373.00           1.0     NaN
#  1375.00           NaN     1.0
#  1380.00           1.0     NaN
#  1400.00           NaN     1.0
#  1417.90           NaN     1.0
# ...                ...     ...
#  176882.44         1.0     NaN
#  186970.17         NaN     1.0
#  188609.63         1.0     NaN
#  196666.67         NaN     1.0
#  197998.39         1.0     NaN
#  205576.89         NaN     1.0
#  212266.67         1.0     NaN
#  213442.17         NaN     1.0
#  225597.21         NaN     1.0
#  237823.33         NaN     1.0
#  248695.43         NaN     1.0
#  258340.00         1.0     NaN
#  275655.50         1.0     NaN
#  277780.92         1.0     NaN
#  290449.43         1.0     NaN
#  290792.00         NaN     1.0
#  307096.00         1.0     NaN
#  318676.33         NaN     1.0
#  325380.24         1.0     NaN
#  360775.50         1.0     NaN
#  364541.67         1.0     NaN
#  461470.24         NaN     1.0
#  476151.83         NaN     1.0
#  478296.43         NaN     1.0
#  489331.83         NaN     1.0
#  588713.60         1.0     NaN
#  771390.96         NaN     1.0
#  834400.00         1.0     NaN
#  1035568.87        1.0     NaN
#  4079625.00        NaN     1.0
#
# [9730 rows x 2 columns]
# {-99.0: 0.6193, 0.0: -0.3059, 1.0: -0.4825, 20.83: 0.0, 50.83: 0.0, 182.0: 0.0, 412.33: 0.0, 567.33: 0.0, 600.17: 0.0, 600.83: 0.0, 767.33: 0.0, 850.48: 0.0, 966.83: 0.0, 1077.35: 0.0, 1106.0: 0.0, 1114.49: 0.0, 1127.67: 0.0, 1170.08: 0.0, 1171.5: 0.0, 1234.0: 0.0, 1245.0: 0.0, 1304.02: 0.0, 1320.02: 0.0, 1348.33: 0.0, 1355.0: 0.0, 1373.0: 0.0, 1375.0: 0.0, 1380.0: 0.0, 1400.0: 0.0, 1417.9: 0.0, 1426.75: 0.0, 1457.83: 0.0, 1466.97: 0.0, 1470.79: 0.0, 1474.67: 0.0, 1478.07: 0.0, 1481.03: 0.0, 1481.61: 0.0, 1483.0: 0.0, 1500.0: 0.0, 1502.81: 0.0, 1525.67: 0.0, 1529.84: 0.0, 1535.92: 0.0, 1546.67: 0.0, 1550.0: 0.0, 1580.0: 0.0, 1580.17: 0.0, 1581.17: 0.0, 1583.0: 0.0, 1587.34: 0.0, 1591.0: 0.0, 1593.5: 0.0, 1608.05: 0.0, 1620.8: 0.0, 1624.67: 0.0, 1639.57: 0.0, 1645.33: 0.0, 1659.08: 0.0, 1675.0: 0.0, 1676.75: 0.0, 1682.5: 0.0, 1687.5: 0.0, 1694.33: 0.0, 1698.21: 0.0, 1698.9: 0.0, 1707.5: 0.0, 1712.5: 0.0, 1721.17: 0.0, 1741.2: 0.0, 1759.5: 0.0, 1767.33: 0.0, 1780.67: 0.0, 1785.46: 0.0, 1788.68: 0.0, 1793.67: 0.0, 1800.0: 0.0, 1807.5: 0.0, 1812.5: 0.0, 1816.17: 0.0, 1822.96: 0.0, 1829.17: 0.0, 1830.27: 0.0, 1832.16: 0.0, 1832.33: 0.0, 1843.6: 0.0, 1850.33: 0.0, 1851.83: 0.0, 1860.26: 0.0, 1861.0: 0.0, 1864.67: 0.0, 1872.33: 0.0, 1873.72: 0.0, 1878.77: 0.0, 1888.5: 0.0, 1900.92: 0.0, 1908.83: 0.0, 1924.67: 0.0, 1927.22: 0.0, 1928.36: 0.0, 1931.77: 0.0, 1950.0: 0.0, 1950.75: 0.0, 1958.83: 0.0, 1961.17: 0.0, 1964.7: 0.0, 1965.67: 0.0, 1983.02: 0.0, 1985.16: 0.0, 1994.67: 0.0, 2000.0: 0.0, 2000.17: 0.0, 2004.37: -0.9525, 2006.2: 0.0, 2007.33: 0.0, 2007.5: 0.0, 2011.22: 0.0, 2012.26: 0.0, 2012.76: 0.0, 2016.33: 0.0, 2017.0: 0.0, 2017.11: 0.0, 2018.54: 0.0, 2023.6: 0.0, 2029.34: 0.0, 2030.5: 0.0, 2031.87: 0.0, 2032.83: 0.0, 2033.0: 0.0, 2033.5: 0.0, 2035.83: 0.0, 2037.87: 0.0, 2038.83: 0.0, 2038.84: 0.0, 2041.56: 0.0, 2045.87: 0.0, 2046.67: 0.0, 2047.2: 0.0, 2047.5: 0.0, 2047.67: 0.0, 2048.9: 0.0, 2049.17: 0.0, 2051.33: 0.0, 2051.67: 0.0, 2054.9: 0.0, 2056.0: 0.0, 2059.29: 0.0, 2059.83: 0.0, 2060.87: 0.0, 2061.5: 0.0, 2062.33: 0.0, 2063.67: 0.0, 2065.0: 0.0, 2066.04: 0.0, 2066.67: 0.0, 2066.83: 0.0, 2067.65: 0.0, 2069.17: 0.0, 2071.6: 0.0, 2071.98: 0.0, 2072.5: 0.0, 2073.71: 0.0, 2076.0: 0.0, 2076.86: 0.0, 2078.0: -0.9525, 2078.32: 0.0, 2079.67: 0.0, 2080.83: 0.0, 2081.5: 0.0, 2083.33: 0.0, 2085.03: 0.0, 2085.83: 0.0, 2087.5: 0.0, 2089.27: 0.0, 2090.0: 0.0, 2091.17: 0.0, 2091.29: 0.0, 2093.24: 0.0, 2094.17: 0.0, 2094.8: 0.0, 2095.17: 0.0, 2096.73: 0.0, 2097.83: 0.0, 2098.29: 0.0, 2099.4: 0.0, 2100.83: 0.0, 2102.17: 0.0, 2102.29: 0.0, 2103.83: 0.0, 2105.33: 0.0, 2105.68: 0.0, 2106.67: 0.0, 2106.83: 0.0, 2107.57: 0.0, 2107.85: 0.0, 2109.17: -0.9525, 2110.83: 0.0, 2112.07: 0.0, 2112.17: 0.0, 2112.5: 0.0, 2113.3: 0.0, 2113.83: 0.0, 2114.17: 0.0, 2115.17: 0.0, 2115.33: 0.0, 2116.67: 0.0, 2116.78: 0.0, 2117.2: 0.0, 2119.02: 0.0, 2119.6: 0.0, 2119.87: 0.0, 2120.74: 0.0, 2121.67: 0.0, 2122.0: 0.0, 2123.83: 0.0, 2126.7: 0.0, 2128.67: 0.0, 2129.55: 0.0, 2130.17: 0.0, 2131.67: 0.0, 2132.98: 0.0, 2133.54: 0.0, 2136.97: 0.0, 2137.27: 0.0, 2138.0: -0.9525, 2138.17: 0.0, 2140.0: 0.0, 2142.82: 0.0, 2145.53: 0.0, 2149.84: 0.0, 2150.67: 0.0, 2151.02: 0.0, 2152.61: 0.0, 2153.61: -0.9525, 2155.97: 0.0, 2157.32: 0.0, 2158.0: 0.0, 2158.33: 0.0, 2158.83: 0.0, 2160.0: 0.0, 2160.33: 0.0, 2160.44: 0.0, 2160.57: 0.0, 2161.5: 0.0, 2161.78: 0.0, 2162.33: 0.0, 2162.95: 0.0, 2163.07: 0.0, 2164.46: 0.0, 2165.33: 0.0, 2165.45: 0.0, 2166.83: 0.0, 2167.17: 0.0, 2168.57: 0.0, 2169.67: 0.0, 2171.61: 0.0, 2172.17: 0.0, 2172.75: 0.0, 2174.02: 0.0, 2175.33: 0.0, 2176.17: 0.0, 2178.0: -0.9525, 2178.73: 0.0, 2181.17: 0.0, 2182.5: 0.0, 2182.9: 0.0, 2183.33: 0.0, 2184.0: 0.0, 2186.5: 0.0, 2186.83: 0.0, 2186.84: 0.0, 2188.02: 0.0, 2188.36: 0.0, 2189.01: 0.0, 2190.0: 0.0, 2191.0: 0.0, 2191.83: 0.0, 2193.17: 0.0, 2193.7: 0.0, 2194.67: 0.0, 2200.0: 0.0, 2200.17: 0.0, 2203.83: 0.0, 2204.83: 0.0, 2206.7: 0.0, 2207.0: 0.0, 2207.11: 0.0, 2208.33: 0.0, 2211.42: 0.0, 2214.68: 0.0, 2215.17 ...
# store_city
# classification    bad   good
# store_city
# 上海              257.0  521.0
# 东营               43.0  143.0
# 中天               49.0  254.0
# 临沂              111.0  339.0
# 保定               99.0  255.0
# 兰州              160.0  629.0
# 北京                8.0  312.0
# 南京               57.0  205.0
# 南宁              300.0  611.0
# 南通               90.0  252.0
# 台州               51.0  144.0
# 合肥              127.0  474.0
# 咸阳              104.0  263.0
# 唐山                NaN   33.0
# 天津               15.0  228.0
# 宁波              221.0  307.0
# 安康               39.0  146.0
# 宝鸡               25.0  117.0
# 常州                NaN   68.0
# 成都              284.0  822.0
# 拉萨               11.0   72.0
# 无锡              209.0  349.0
# 昆明              234.0  574.0
# 杭州               10.0  170.0
# 柳州              114.0  171.0
# 汉中               53.0  167.0
# 泰安              112.0  224.0
# 济南              111.0  431.0
# 济宁              115.0  270.0
# 淄博              121.0  323.0
# 滨州               88.0  125.0
# 潍坊              166.0  305.0
# 烟台              166.0  174.0
# 玉林               86.0  211.0
# 石家庄             173.0  565.0
# 苏州               97.0  159.0
# 襄阳              148.0  244.0
# 西宁               61.0  260.0
# 西安              206.0  597.0
# 贵阳              209.0  416.0
# 遵义              142.0  111.0
# 郑州              209.0  430.0
# 重庆               43.0  296.0
# 钦州               61.0  169.0
# 银川              119.0  142.0
# 镇江               74.0  219.0
# 长沙                7.0  153.0
# 青岛               53.0  128.0
# {'上海': -0.2458, '东营': 0.2491, '中天': 0.693, '临沂': 0.164, '保定': -0.0064, '兰州': 0.4164, '北京': 2.7111, '南京': 0.3274, '南宁': -0.2412, '南通': 0.0771, '台州': 0.0855, '合肥': 0.3645, '咸阳': -0.0247, '唐山': 0.0, '天津': 1.7688, '宁波': -0.6238, '安康': 0.3675, '宝鸡': 0.5908, '常州': 0.0, '成都': 0.1103, '拉萨': 0.9263, '无锡': -0.4398, '昆明': -0.0552, '杭州': 1.8807, '柳州': -0.547, '汉中': 0.1952, '泰安': -0.2594, '济南': 0.4041, '济宁': -0.099, '淄博': 0.0294, '滨州': -0.6015, '潍坊': -0.3442, '烟台': -0.9054, '玉林': -0.055, '石家庄': 0.231, '苏州': -0.4583, '襄阳': -0.4526, '西宁': 0.4973, '西安': 0.1115, '贵阳': -0.2642, '遵义': -1.1988, '郑州': -0.2311, '重庆': 0.9766, '钦州': 0.0665, '银川': -0.7758, '镇江': 0.1325, '长沙': 2.132, '青岛': -0.0708}
# idcard_area
# classification   bad  good
# idcard_area
# 偏远区县            2872  7015
# 县级市              594  1306
# 市区              1433  4667
# 村、乡              339   590
# {'偏远区县': -0.0595, '县级市': -0.1647, '市区': 0.2282, '村、乡': -0.3984}
